# %% [markdown]
# <center><font size="6"><b>CV SEGA</b></font></center>
# <p></p>
# <center><font size="5"><b>Modélisation pour détection des bennes</b></font></center>
# <br>
# <br>
# <br>

# %% [markdown]
# # Intentions

# %% [markdown]
# Détecter et entourer les bennes via des bounding box.

# %% [markdown]
# # Logs

# %% [markdown]
# Voir CV_SEGA_model_objdetect_versions.md

# %% [markdown]
# # Configuration du notebook

# %%
# Mode d'éxécution du notebook : "drive" ou "local"
work_mode = "local"

# Localisation des modèles pour les sauvegardes et les chargements
if work_mode == "drive":
    model_loc = "/drive/My Drive/CV_DS/..."
elif work_mode == "local":
    model_loc = "_models"

# %%
# %%javascript
# // Récupération du nom du notebook
# var kernel = IPython.notebook.kernel;
# var body = document.body,
#     attribs = body.attributes;
# var command = "theNotebook = " + "'"+attribs['data-notebook-name'].value+"'";
# kernel.execute(command);

# %%
# Récupération du nom notebook pour les sauvegardes de modèles et connection au drive et montage du drive
if work_mode == "drive":
    # Montage du drive
    from requests import get
    theNotebook = get('http://172.28.0.2:9000/api/sessions').json()[0]['name']
    theNotebook = theNotebook[0:-6]
    print("Nom du notebook : ",theNotebook)
    
    # Montage du drive
    from google.colab import  drive
    drive.mount('/content/drive')

# %% [markdown]
# # Installer

# %%
if work_mode == "drive":
    # !pip install swifter

# %% [markdown]
# # Modules et fonctions

# %% [markdown]
# ## Import des modules

# %%
# Classics
import pandas as pd
import numpy as np
import random

# Opérations sur fichiers/dossiers
import os
from joblib import load, dump
import json

# Viz
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import missingno as msno
# %matplotlib inline

# Autres
from tqdm import tqdm
from collections import Counter
import pprint

# Tensorflow
import tensorflow as tf

# Preprocess
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## La cuisine

# %%
# Fonction d'affichage des BB
def show_img_bb (img, x, y, w, h,name):
    
    # Calcul des coordonnées
    x1 = np.abs(x)
    y1 = np.abs(y)
    w = np.abs(w)
    h = np.abs(h)
    x2= x1+w
    y2= y1+h
    
    # Affichage des coordonnées
    print(f"Coordonnées BB {name}")
    print(f'x:{x}',f'y:{y}',f'w:{w}',f'h:{h}')
    print(f'x1:{x1}',f'x2:{x2}',f'y1:{y1}',f'y2:{y2}')
    
    plt.imshow(img)
    plt.plot([x1,x2,x2,x1,x1], [y1,y1,y2,y2,y1], "r")
    plt.title("Image : " + name)
#     plt.show()

# %% [markdown]
# ## Test GPU

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
sys_details = tf.sysconfig.get_build_info()
if tf.test.gpu_device_name():
    device_name = tf.test.gpu_device_name()
    print(f'GPU found : {device_name}')
    pprint.print(sys_details)
else:
    tf.config.list_physical_devices('CPU')
    print("No GPU found, CPU mode activated")
    pprint.pprint(sys_details)
# Out:
# No GPU found, CPU mode activated
# OrderedDict([('cpu_compiler',
#               'C:/Program Files (x86)/Microsoft Visual '
#               'Studio/2019/Community/VC/Tools/MSVC/14.29.30133/bin/HostX64/x64/cl.exe'),
#              ('cuda_compute_capabilities',
#               ['sm_35', 'sm_50', 'sm_60', 'sm_70', 'sm_75', 'compute_80']),
#              ('cuda_version', '64_112'),
#              ('cudart_dll_name', 'cudart64_112.dll'),
#              ('cudnn_dll_name', 'cudnn64_8.dll'),
#              ('cudnn_version', '64_8'),
#              ('is_cuda_build', True),
#              ('is_rocm_build', False),
#              ('is_tensorrt_build', False),
#              ('msvcp_dll_names', 'msvcp140.dll,msvcp140_1.dll'),
#              ('nvcuda_dll_name', 'nvcuda.dll')])

# %% [markdown]
# # Chargement du dataset

# %%
# Lecture des données
if work_mode == "local":
#     data_path = "Z:/_pyworld/_kindergarten/_T_Datascientest/Projet cv SEGA/SEGA/datasets/container"
    data_path = "E:/OneDrive/_forge/SEGA/datasets/container"

df = pd.read_csv(data_path + '/df_1_light.csv',index_col=0,converters={'bbox': pd.eval})
df = df.astype({'file_name':'string'})
df["file_name"] = df["file_name"].apply(lambda x: data_path + "/" + x)
display (df.info())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1483 entries, 0 to 1482
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   file_name  1483 non-null   object
#  1   bbox       1483 non-null   object
# dtypes: object(2)
# memory usage: 34.8+ KB
# None
#                                            file_name                 bbox
# 0  E:/OneDrive/_forge/SEGA/datasets/container/000...    [10, 0, 535, 289]
# 1  E:/OneDrive/_forge/SEGA/datasets/container/000...   [18, 46, 400, 224]
# 2  E:/OneDrive/_forge/SEGA/datasets/container/000...    [1, 51, 703, 606]
# 3  E:/OneDrive/_forge/SEGA/datasets/container/000...   [0, 135, 493, 287]
# 4  E:/OneDrive/_forge/SEGA/datasets/container/000...  [556, 77, 233, 186]

# %%
# Filtrage uniquement sur les formats JPEG
df = df[df["file_name"].str.contains(".jpeg")]

# %%
# Récupération de la liste des doublons
list_double = list(df.loc[df.astype(str).duplicated(subset = ["file_name"],keep = 'last'),:].index)

print("liste de doublons :", list_double)
# Out:
# liste de doublons : [3, 4, 6, 8, 12, 16, 17, 20, 21, 31, 33, 37, 40, 41, 42, 44, 50, 55, 59, 66, 69, 70, 72, 73, 76, 77, 79, 93, 107, 109, 117, 120, 127, 128, 131, 132, 134, 135, 138, 139, 140, 148, 149, 150, 151, 152, 153, 154, 161, 169, 171, 180, 183, 197, 200, 202, 203, 208, 212, 224, 241, 242, 243, 244, 258, 269, 272, 277, 282, 297, 299, 300, 316, 327, 331, 336, 339, 344, 351, 366, 370, 377, 384, 386, 391, 392, 401, 410, 417, 433, 434, 440, 452, 453, 460, 474, 476, 477, 480, 481, 483, 486, 488, 490, 491, 492, 493, 495, 507, 512, 514, 516, 517, 518, 524, 525, 536, 553, 563, 564, 565, 569, 573, 575, 579, 580, 581, 587, 594, 596, 601, 608, 609, 629, 630, 634, 648, 650, 652, 658, 660, 664, 665, 666, 673, 676, 677, 683, 689, 694, 703, 704, 707, 711, 715, 716, 718, 726, 727, 732, 739, 740, 748, 751, 756, 761, 762, 771, 774, 781, 783, 784, 805, 807, 810, 814, 816, 818, 819, 823, 829, 834, 835, 836, 845, 846, 848, 849, 853, 854, 858, 859, 886, 891, 902, 905, 920, 927, 931, 932, 935, 936, 937, 954, 960, 986, 989, 1002, 1003, 1012, 1016, 1018, 1019, 1023, 1033, 1038, 1039, 1064, 1077, 1085, 1087, 1091, 1099, 1112, 1113, 1122, 1125, 1126, 1127, 1133, 1135, 1136, 1141, 1145, 1146, 1147, 1148, 1150, 1152, 1153, 1154, 1158, 1160, 1169, 1170, 1171, 1172, 1175, 1176, 1181, 1182, 1183, 1190, 1191, 1194, 1198, 1199, 1205, 1207, 1217, 1218, 1220, 1226, 1229, 1230, 1231, 1233, 1236, 1239, 1240, 1242, 1243, 1244, 1246, 1248, 1259, 1261, 1264, 1269, 1272, 1276, 1278, 1281, 1284, 1285, 1287, 1290, 1298, 1300, 1303, 1305, 1312, 1317, 1335, 1338, 1340, 1343, 1346, 1348, 1363, 1367, 1371, 1372, 1376, 1378, 1380, 1384, 1391, 1392, 1401, 1403, 1412, 1413, 1418, 1421, 1422, 1423, 1428, 1430, 1432, 1433, 1434, 1435, 1436, 1441, 1445, 1446, 1449, 1453, 1460, 1462, 1464, 1466, 1471, 1473, 1480, 1481]

# %%
# On chute les cas ou il y a plus d'une BB
df.drop(index=list_double, inplace = True)
df.reset_index(drop=True, inplace=True)

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Séparation

# %%
################ Réalisation des sets d'entrainnement et de tests
"""
    taille du set de test => 10 % des données restantes
    random_state => 42
"""

# Séparer la variable explicative de la variable à prédire
X, y = df["file_name"], df["bbox"].apply(lambda x: np.array(x)).to_list()

X_train, X_test, y_train, y_test  = train_test_split(np.array(X), np.array(y), test_size=0.1,random_state = 42)

# %% [markdown]
# ## Fonction de chargement

# %%
# Fonction de chargement des images via un numpy array ou un chemin
@tf.function
def magic_loader (X, y, fromfile = False, norm = True, resize = None):   
    
    # ==== Chargement de l'image
    if fromfile == True:
        image = tf.io.read_file(X, name=None)
        image = tf.io.decode_image(image,channels=3,expand_animations=False)     
     
    else:
        image = tf.convert_to_tensor(X)

    # ==== Normalisation    
    if norm :
        image = tf.divide(image, 255)
    
    # ==== Redimensionnement  
    if resize!= None:
        # Récupération de l'ancienne taille de l'image
        old_size = tf.shape(image)[:2]

        # Définition de la taille cible de l'image
        img_size = tf.constant(resize)

        # Redimensionnement
        image = tf.image.resize(image,
                             img_size,
                             method='nearest',
                             preserve_aspect_ratio=False,
                             antialias=False,
                             name=None)
        
        # Calcul du ratio de redimensionnement pour adapter les bounding boxs
        ratio = tf.math.divide(img_size,old_size)
        ratio = tf.cast(ratio, dtype="float32")
        

        
        # Redimensionnement des bounding boxs
        y = tf.convert_to_tensor(y)
        y = tf.cast(y, dtype="float32")/255
        x_sized = y[0]*ratio[1]
        y_sized = y[1]*ratio[0]
        w_sized = y[2]*ratio[1]
        h_sized = y[3]*ratio[0]
        y_new = tf.stack([x_sized,y_sized,w_sized,h_sized],0)

    else:
        y_new = y

    return image, y_new

# %%
# ================================================================================================
# Définition de l'image pour test de la fonction de chargement d'image
i = random.choices(list(df.index), k=1)[0]
img_path = df.loc[i,"file_name"]
imgRsize = (256, 256)

# ================================================================================================
# Test de la fonction
image = plt.imread(img_path)

print("==== Avant ====")
print(image.shape)
print(df.loc[i,"bbox"])
show_img_bb (image, df.loc[i,"bbox"][0], df.loc[i,"bbox"][1], df.loc[i,"bbox"][2], df.loc[i,"bbox"][3], df.loc[i,"file_name"] )
plt.show()

# Application de la fonction fonctions
image_new, y_new = magic_loader(img_path, df.loc[i,"bbox"],
                                fromfile = True,
                                norm = True,
                                resize = (imgRsize[0], imgRsize[0])
                               )

print("==== Après ====")
print(image_new.shape)
print(y_new)
show_img_bb (image_new, y_new[0]*255, y_new[1]*255, y_new[2]*255, y_new[3]*255, df.loc[i,"file_name"] )
plt.show()
# Out:
# ==== Avant ====
# (275, 183, 3)
# [0, 133, 182, 141]
# Coordonnées BB E:/OneDrive/_forge/SEGA/datasets/container/00727.jpeg
# x:0 y:133 w:182 h:141
# x1:0 x2:182 y1:133 y2:274
# ==== Après ====
# (256, 256, 3)
# tf.Tensor([0.        0.485533  0.9984357 0.514738 ], shape=(4,), dtype=float32)
# Coordonnées BB E:/OneDrive/_forge/SEGA/datasets/container/00727.jpeg
# x:0.0 y:123.8109130859375 w:254.60110473632812 h:131.25819396972656
# x1:0.0 x2:254.60110473632812 y1:123.8109130859375 y2:255.06910705566406

# %% [markdown]
# ## Générateur de données

# %%
batch_size = 8
imgRsize = (256, 256)
AUTO = tf.data.experimental.AUTOTUNE

# Train
dataset_train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
dataset_train = dataset_train.shuffle(len(X_train)).map(lambda x, y : magic_loader(x,
                                                                                   y,
                                                                                   fromfile = True,
                                                                                   norm = True,
                                                                                   resize = imgRsize
                                                                                  ), num_parallel_calls=-1
                                                       )\
                                                    .batch(batch_size,drop_remainder=True)\
                                                    .cache()\
                                                    .prefetch(AUTO)\
                                                    .repeat(-1)
# Test
dataset_test = tf.data.Dataset.from_tensor_slices((X_test, y_test))
dataset_test = dataset_test.shuffle(len(X_test)).map(lambda x, y : magic_loader(x,
                                                                                y,
                                                                                fromfile = True,
                                                                                norm = True,
                                                                                resize = imgRsize
                                                                               ))\
                                                    .batch(batch_size,drop_remainder=True)\
                                                    .cache()\
                                                    .prefetch(AUTO)\
                                                    .repeat(-1)
# # Val
# dataset_val = tf.data.Dataset.from_tensor_slices((X_val, y_val))
# dataset_val = dataset_test.shuffle(len(X_val)).map(lambda x, y : magic_loader(x,
#                                                                               y,
#                                                                               fromfile = True,
#                                                                               norm = True,
#                                                                               resize = imgRsize
#                                                                              ))\
#                                                     .batch(batch_size,drop_remainder=True)\
#                                                     .cache()\
#                                                     .prefetch(AUTO)\
#                                                     .repeat(-1)

# %%
# Visualisation des sorties du générateur train

X_t, y_t = next(iter(dataset_train))

for img,bbox in zip(X_t, y_t):
#     print(i,img.shape)
    show_img_bb (img, bbox[0]*255, bbox[1]*255, bbox[2]*255, bbox[3]*255, "X" )
    plt.show()
# Out:
# Coordonnées BB X
# x:122.77550506591797 y:168.31805419921875 w:66.61224365234375 h:77.89602661132812
# x1:122.77550506591797 x2:189.38775634765625 y1:168.31805419921875 y2:246.21408081054688
# Coordonnées BB X
# x:12.840126037597656 y:66.43038177490234 w:114.75862121582031 h:150.6835479736328
# x1:12.840126037597656 x2:127.59874725341797 y1:66.43038177490234 y2:217.11392211914062
# Coordonnées BB X
# x:24.754718780517578 y:34.37455749511719 w:185.9622802734375 h:202.6289825439453
# x1:24.754718780517578 x2:210.7169952392578 y1:34.37455749511719 y2:237.0035400390625
# Coordonnées BB X
# x:1.1034482717514038 y:11.797235488891602 w:233.93104553222656 h:241.84332275390625
# x1:1.1034482717514038 x2:235.0345001220703 y1:11.797235488891602 y2:253.64056396484375
# Coordonnées BB X
# x:61.29230880737305 y:58.994869232177734 w:194.4615478515625 h:94.19486999511719
# x1:61.29230880737305 x2:255.7538604736328 y1:58.994869232177734 y2:153.1897430419922
# Coordonnées BB X
# x:58.442108154296875 y:26.666667938232422 w:84.21052551269531 h:91.02223205566406
# x1:58.442108154296875 x2:142.6526336669922 y1:26.666667938232422 y2:117.68890380859375
# Coordonnées BB X
# x:23.68000030517578 y:33.706668853759766 w:232.3199920654297 h:222.29335021972656
# x1:23.68000030517578 x2:256.0 y1:33.706668853759766 y2:256.0000305175781
# Coordonnées BB X
# x:42.809364318847656 y:42.66666793823242 w:196.92308044433594 h:201.1428680419922
# x1:42.809364318847656 x2:239.73245239257812 y1:42.66666793823242 y2:243.80953979492188

# %%
# Définition d'un générateur python
def generator(dataset):
    iterator = iter(dataset)
    while True:
        X, y = next(iterator)
        yield X, y

# Définition du générateur final.
gen_train = generator(dataset_train)
gen_test = generator(dataset_test)

# %% [markdown]
# # Modélisation

# %% [markdown]
# ## Partrie encoder

# %%
from tensorflow.keras.applications import EfficientNetB0

# Load the model efficientNet
efficientNet = EfficientNetB0(include_top=False, input_shape=(imgRsize[0],imgRsize[1],3))

# Freeze the blackbone
for layer in efficientNet.layers:
    layer.trainable = False

# %% [markdown]
# ## Partie régression

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, MaxPooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.models import Model, Sequential, load_model

model = Sequential()
model.add(efficientNet)
model.add(GlobalAveragePooling2D())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(4, activation='linear'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 8, 8, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 5,888,167
# Trainable params: 1,838,596
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %% [markdown]
# ## Fonction de perte

# %%
def coord_loss(y_true, y_pred):
    
    # Conversion en tenseurs
    y_true = tf.convert_to_tensor(y_true)
    y_pred = tf.convert_to_tensor(y_pred)
    
    # Répartition des valeurs
    xpred = y_pred[:,0]
    xtrue = y_true[:,0]
    ypred = y_pred[:,1]
    ytrue = y_true[:,1]
    wpred = y_pred[:,2]
    wtrue = y_true[:,2]
    hpred = y_pred[:,3]
    htrue = y_true[:,3]
    
    # Calcul des différents membres de la formule
    a = tf.math.square(xpred - xtrue)
    b = tf.math.square(ypred - ytrue)
    c = tf.math.square(tf.math.sqrt(tf.math.abs(wpred))-tf.math.sqrt(wtrue))
    d = tf.math.square(tf.math.sqrt(tf.math.abs(hpred))-tf.math.sqrt(htrue))

    return tf.reduce_mean((a + b + c + d), axis=-1)

# %% [markdown]
# ## Compilation

# %%
from tensorflow.keras.optimizers import SGD, Adam, RMSprop

model.compile(loss=coord_loss,
              optimizer=Adam(0.01),
              metrics = [tf.keras.metrics.MeanSquaredError()]
             )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 8, 8, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 5,888,167
# Trainable params: 1,838,596
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %% [markdown]
# ## Callbacks

# %%
from tensorflow.keras import callbacks

# %%
# Réduction du lr sur un plateau
lr_plateau = callbacks.ReduceLROnPlateau(monitor='val_loss',
                                         patience=4,
                                         verbose=2,
                                         mode='min')

# %%
# Callback pour l'arrêt anticipé si les perfos ne s'améliorent pas.
early_stopping = callbacks.EarlyStopping(monitor='val_loss',
                                         patience=10,
                                         mode='min',
                                         restore_best_weights=True)

# %% [markdown]
# ## Entrainement

# %%
nb_epochs = 40
history = model.fit(dataset_train,
                    steps_per_epoch = (int(len(X_train)//batch_size)),
                    epochs=nb_epochs,
                    validation_data = dataset_train,
                    validation_steps = (int(len(X_test)//batch_size)),
                    callbacks=[early_stopping,lr_plateau]
                   )
# Out:
# Epoch 1/40
# 128/128 [==============================] - 66s 469ms/step - loss: 0.2935 - mean_squared_error: 0.4801 - val_loss: 0.1310 - val_mean_squared_error: 0.5288 - lr: 0.0010
# Epoch 2/40
# 128/128 [==============================] - 53s 412ms/step - loss: 0.1407 - mean_squared_error: 0.4618 - val_loss: 0.1266 - val_mean_squared_error: 0.4408 - lr: 0.0010
# Epoch 3/40
# 128/128 [==============================] - 48s 378ms/step - loss: 0.1375 - mean_squared_error: 0.4638 - val_loss: 0.1251 - val_mean_squared_error: 0.4656 - lr: 0.0010
# Epoch 4/40
# 128/128 [==============================] - 50s 393ms/step - loss: 0.1379 - mean_squared_error: 0.4607 - val_loss: 0.1258 - val_mean_squared_error: 0.4842 - lr: 0.0010
# Epoch 5/40
# 128/128 [==============================] - 49s 382ms/step - loss: 0.1362 - mean_squared_error: 0.4641 - val_loss: 0.1227 - val_mean_squared_error: 0.4531 - lr: 0.0010
# Epoch 6/40
# 128/128 [==============================] - 52s 410ms/step - loss: 0.1344 - mean_squared_error: 0.4584 - val_loss: 0.1265 - val_mean_squared_error: 0.4464 - lr: 0.0010
# Epoch 7/40
# 128/128 [==============================] - 56s 437ms/step - loss: 0.1330 - mean_squared_error: 0.4580 - val_loss: 0.1227 - val_mean_squared_error: 0.4540 - lr: 0.0010
# Epoch 8/40
# 128/128 [==============================] - 50s 387ms/step - loss: 0.1294 - mean_squared_error: 0.4563 - val_loss: 0.1238 - val_mean_squared_error: 0.4581 - lr: 0.0010
# Epoch 9/40
# 128/128 [==============================] - ETA: 0s - loss: 0.1274 - mean_squared_error: 0.4570
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 128/128 [==============================] - 49s 383ms/step - loss: 0.1274 - mean_squared_error: 0.4570 - val_loss: 0.1235 - val_mean_squared_error: 0.4776 - lr: 0.0010
# Epoch 10/40
# 128/128 [==============================] - 48s 378ms/step - loss: 0.1247 - mean_squared_error: 0.4623 - val_loss: 0.1221 - val_mean_squared_error: 0.4506 - lr: 1.0000e-04
# Epoch 11/40
# 128/128 [==============================] - 50s 392ms/step - loss: 0.1241 - mean_squared_error: 0.4587 - val_loss: 0.1222 - val_mean_squared_error: 0.4522 - lr: 1.0000e-04
# Epoch 12/40
# 128/128 [==============================] - 49s 381ms/step - loss: 0.1232 - mean_squared_error: 0.4581 - val_loss: 0.1221 - val_mean_squared_error: 0.4473 - lr: 1.0000e-04
# Epoch 13/40
# 128/128 [==============================] - 50s 390ms/step - loss: 0.1244 - mean_squared_error: 0.4568 - val_loss: 0.1219 - val_mean_squared_error: 0.4458 - lr: 1.0000e-04
# Epoch 14/40
# 128/128 [==============================] - 49s 385ms/step - loss: 0.1247 - mean_squared_error: 0.4545 - val_loss: 0.1218 - val_mean_squared_error: 0.4474 - lr: 1.0000e-04
# Epoch 15/40
# 128/128 [==============================] - 48s 379ms/step - loss: 0.1237 - mean_squared_error: 0.4566 - val_loss: 0.1219 - val_mean_squared_error: 0.4474 - lr: 1.0000e-04
# Epoch 16/40
# 128/128 [==============================] - 51s 396ms/step - loss: 0.1239 - mean_squared_error: 0.4594 - val_loss: 0.1221 - val_mean_squared_error: 0.4498 - lr: 1.0000e-04
# Epoch 17/40
# 128/128 [==============================] - ETA: 0s - loss: 0.1237 - mean_squared_error: 0.4570
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 128/128 [==============================] - 49s 381ms/step - loss: 0.1237 - mean_squared_error: 0.4570 - val_loss: 0.1219 - val_mean_squared_error: 0.4516 - lr: 1.0000e-04
# Epoch 18/40
# 128/128 [==============================] - 50s 388ms/step - loss: 0.1232 - mean_squared_error: 0.4587 - val_loss: 0.1219 - val_mean_squared_error: 0.4513 - lr: 1.0000e-05
# Epoch 19/40
# 128/128 [==============================] - 49s 382ms/step - loss: 0.1236 - mean_squared_error: 0.4592 - val_loss: 0.1219 - val_mean_squared_error: 0.4511 - lr: 1.0000e-05
# Epoch 20/40
# 128/128 [==============================] - 49s 386ms/step - loss: 0.1234 - mean_squared_error: 0.4584 - val_loss: 0.1219 - val_mean_squared_error: 0.4503 - lr: 1.0000e-05
# Epoch 21/40
# 128/128 [==============================] - ETA: 0s - loss: 0.1240 - mean_squared_error: 0.4585
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 128/128 [==============================] - 49s 386ms/step - loss: 0.1240 - mean_squared_error: 0.4585 - val_loss: 0.1218 - val_mean_squared_error: 0.4499 - lr: 1.0000e-05
# Epoch 22/40
# 128/128 [==============================] - 49s 381ms/step - loss: 0.1238 - mean_squared_error: 0.4572 - val_loss: 0.1218 - val_mean_squared_error: 0.4499 - lr: 1.0000e-06
# Epoch 23/40
# 128/128 [==============================] - 52s 404ms/step - loss: 0.1237 - mean_squared_error: 0.4585 - val_loss: 0.1218 - val_mean_squared_error: 0.4499 - lr: 1.0000e-06
# Epoch 24/40
# 128/128 [==============================] - 51s 399ms/step - loss: 0.1228 - mean_squared_error: 0.4604 - val_loss: 0.1218 - val_mean_squared_error: 0.4498 - lr: 1.0000e-06

# %%
# Config
first_var = 'loss'
second_var = 'mean_squared_error'
history = history

# Mise à l'échelle des nb d'epochs
tick_locs = list(range(0,nb_epochs))
tick_lbls = list(range(1,nb_epochs+1))

plt.figure(figsize=(14,4))
# Graphe var 1
plt.subplot(121)
plt.plot(history.history[first_var])
plt.plot(history.history['val_'+first_var])
plt.title(f'Model {first_var} by epoch')
plt.ylabel(first_var)
plt.xlabel('epoch')
plt.xticks(tick_locs, tick_lbls)
plt.legend(['train', 'validation'], loc='best')

# Graphe var 2
plt.subplot(122)
plt.plot(history.history[second_var])
plt.plot(history.history['val_'+second_var])
plt.title(f'Model {second_var} by epoch')
plt.ylabel(second_var)
plt.xlabel('epoch')
plt.xticks(tick_locs, tick_lbls, rotation = 90)
plt.legend(['train', 'validation'], loc='best')
plt.show()

# %% [markdown]
# ## Inférence

# %%
X_t, y_t = next(gen_test)

# %%
# Définition de l'image et des coordonnées pour test du modèle
i = random.choices(list(range(batch_size)), k=1)[0]
img_ori = X_t[i]
coord_ori = y_t[i]

# Affichage de la BB d'origine
print("==== Image et BB source ====")
show_img_bb (img_ori, coord_ori[0], coord_ori[1], coord_ori[2], coord_ori[3], "X" )
plt.show()

# Affichage de la BB prédite
print("==== Image et BB après prédiction ====")
x, y, w, h, p = model.predict(tf.expand_dims(X_t[i], axis=0))[0]
print(f"Probabilité de présence d'objet : {p}")
show_img_bb (img_ori, x*255, y*255, w*255, h*255, "X" )
plt.show()
# Out:
# ==== Image et BB source ====
# Coordonnées BB X
# x:0.1813102513551712 y:0.005975724197924137 w:0.7017378211021423 h:0.9859944581985474
# x1:0.1813102513551712 x2:0.8830480575561523 y1:0.005975724197924137 y2:0.9919701814651489
# ==== Image et BB après prédiction ====
# 1/1 [==============================] - 2s 2s/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 13>()
#      11 # Affichage de la BB prédite
#      12 print("==== Image et BB après prédiction ====")
# ---> 13 x, y, w, h, p = model.predict(tf.expand_dims(X_t[i], axis=0))[0]
#      14 print(f"Probabilité de présence d'objet : {p}")
#      15 show_img_bb (img_ori, x*255, y*255, w*255, h*255, "X" )
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
for img in X_t:
    print("==== Image et BB après prédiction ====")
#     print(f"Probabilité de présence d'objet : {p}")
    x, y, w, h = model.predict(tf.expand_dims(img, axis=0))[0]
    show_img_bb (img, x*255, y*255, w*255, h*255, "X" )
    plt.show()
# Out:
# ==== Image et BB après prédiction ====
# 1/1 [==============================] - 0s 67ms/step
# Coordonnées BB X
# x:37.856198251247406 y:55.75324930250645 w:175.22574305534363 h:158.4615594148636
# x1:37.856198251247406 x2:213.08194130659103 y1:55.75324930250645 y2:214.21480871737003
# ==== Image et BB après prédiction ====
# 1/1 [==============================] - 0s 72ms/step
# Coordonnées BB X
# x:37.854207158088684 y:55.74590049684048 w:175.1379069685936 h:158.3694675564766
# x1:37.854207158088684 x2:212.99211412668228 y1:55.74590049684048 y2:214.11536805331707
# ==== Image et BB après prédiction ====
# 1/1 [==============================] - 0s 69ms/step
# Coordonnées BB X
# x:37.842511385679245 y:55.74870474636555 w:175.10436236858368 h:158.31798791885376
# x1:37.842511385679245 x2:212.94687375426292 y1:55.74870474636555 y2:214.0666926652193
# ==== Image et BB après prédiction ====
# 1/1 [==============================] - 0s 94ms/step
# Coordonnées BB X
# x:37.847390323877335 y:55.76125167310238 w:175.25849729776382 h:158.4787952899933
# x1:37.847390323877335 x2:213.10588762164116 y1:55.76125167310238 y2:214.24004696309566
# ==== Image et BB après prédiction ====
# 1/1 [==============================] - 0s 76ms/step
# Coordonnées BB X
# x:37.85557508468628 y:55.74439957737923 w:175.12858986854553 h:158.36144238710403
# x1:37.85557508468628 x2:212.9841649532318 y1:55.74439957737923 y2:214.10584196448326
# ==== Image et BB après prédiction ====
# 1/1 [==============================] - 0s 73ms/step
# Coordonnées BB X
# x:37.853865176439285 y:55.75868681073189 w:175.28736054897308 h:158.53311717510223
# x1:37.853865176439285 x2:213.14122572541237 y1:55.75868681073189 y2:214.29180398583412
# ==== Image et BB après prédiction ====
# 1/1 [==============================] - 0s 68ms/step
# Coordonnées BB X
# x:37.856411039829254 y:55.76025612652302 w:175.3165277838707 h:158.56568902730942
# x1:37.856411039829254 x2:213.17293882369995 y1:55.76025612652302 y2:214.32594515383244
# ==== Image et BB après prédiction ====
# 1/1 [==============================] - 0s 70ms/step
# Coordonnées BB X
# x:37.851471304893494 y:55.74628807604313 w:175.12390851974487 h:158.3487206697464
# x1:37.851471304893494 x2:212.97537982463837 y1:55.74628807604313 y2:214.09500874578953

# %%
model.predict(X_t)

# %% [markdown]
# # Bac à sable
